# %%
from ultralytics import YOLO

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
model = YOLO("best.pt")

# %%
# model = '/content/runs/detect/train/weights/best.pt'

sou = "https://www.youtube.com/watch?v=Jlp8G9paliw"

results = model(sou, stream=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/3492 c:\Users\mistr\Desktop\New folder\valid\images\00002_00004_jpg.rf.f6b9d9815b6dd2a1eb10e71369ca0a13.jpg: 640x640 (no detections), 1059.3ms
# image 2/3492 c:\Users\mistr\Desktop\New folder\valid\images\00005_00001_jpg.rf.9b67d5428c930f3f141af95203021a61.jpg: 640x640 (no detections), 1095.1ms
# ...
